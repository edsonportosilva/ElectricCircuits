# %%
if 'google.colab' in str(get_ipython()):    
    ! git clone -b master https://github.com/edsonportosilva/ElectricCircuits
    from os import chdir as cd
    cd('/content/ElectricCircuits/')
    ! pip install -e .
    ! pip install SciencePlots

import sympy as sp
from sympy import latex
import numpy as np
from circuit.utils import symdisp, symplot
from IPython.display import Math, Latex, display
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science','ieee'])

# %%
# definindo variável tempo
t = sp.symbols('t', real=True)

i = 5*sp.exp(-100*t)
v = 400*sp.exp(-100*t)

p = v*i

symdisp('i(t) = ', i, 'A')
symdisp('v(t) = ', v, 'V')
symdisp('p(t) = ', p, 'W')
# Out:
# $\displaystyle i(t) = 5 e^{- 100 t}\;\mathrm{A}$
# $\displaystyle v(t) = 400 e^{- 100 t}\;\mathrm{V}$
# $\displaystyle p(t) = 2000 e^{- 200 t}\;\mathrm{W}$

# %%
intervalo = np.linspace(0, 0.05, 1000)

symplot(t, v, intervalo, funLabel='$v(t) = 400e^{-100t}\; V$', 
        xlabel = 'Tempo [ms]',
        ylabel='Tensão [V]', 
        figsize=(2,2),
        xfactor=1e-3,
        yfactor=1)

# %%
symplot(t, i, intervalo, funLabel='$i(t) = 5e^{-100t}\; A$', 
        xlabel = 'Tempo [ms]',
        ylabel='Corrente [A]', 
        figsize=(2,2),
        xfactor=1e-3)

# %%
symplot(t, p, intervalo, funLabel='$p(t) = 2000e^{-200t}\; W$', 
        xlabel = 'Tempo [ms]',
        ylabel='Potência [W]', 
        figsize=(2,2),
        xfactor=1e-3)

# %%
symdisp('w_{total} = \int_0^\infty p(t)dt ='+ f'\int_0^\infty {latex(p)}dt =', sp.integrate(p, (t, 0, 1.0)), 'J')
# Out:
# $\displaystyle w_{total} = \int_0^\infty p(t)dt =\int_0^\infty 2000 e^{- 200 t}dt =10.0\;\mathrm{J}$
