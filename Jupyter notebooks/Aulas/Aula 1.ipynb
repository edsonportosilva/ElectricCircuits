# %%
if 'google.colab' in str(get_ipython()):    
    ! git clone -b master https://github.com/edsonportosilva/ElectricCircuits
    from os import chdir as cd
    cd('/content/ElectricCircuits/')
    ! pip install -e .

import sympy as sp
import numpy as np
from circuit.utils import symdisp, symplot
from IPython.display import Math, Latex, display
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science','ieee'])

# %%
# definindo variável tempo
t = sp.symbols('t', real=True)

i = 5*sp.exp(-100*t)
v = 400*sp.exp(-100*t)

p = v*i

symdisp('i(t) = ', i, 'A')
symdisp('v(t) = ', v, 'V')
symdisp('p(t) = ', p, 'W')
# Out:
# $\displaystyle i(t) = 5 e^{- 100 t}\;\mathrm{A}$
# $\displaystyle v(t) = 400 e^{- 100 t}\;\mathrm{V}$
# $\displaystyle p(t) = 2000 e^{- 200 t}\;\mathrm{W}$

# %%
intervalo = np.linspace(0, 0.05, 1000)

symplot(t, v, intervalo, funLabel='$v(t)$', figsize=(4,2))

# %%
symplot(t, i, intervalo, funLabel='$i(t)$')

# %%
symplot(t, p, intervalo, funLabel='$p(t)$')

# %%
sp.integrate(p, (t, 0, 1.0))
# Out:
# 10.0000000000000
