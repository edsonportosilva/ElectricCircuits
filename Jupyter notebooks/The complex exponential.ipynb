# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonportosilva/ElectricCircuits/blob/master/Jupyter%20notebooks/Visualize%20convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import HTML
from IPython.display import Image
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

if 'google.colab' in str(get_ipython()):    
    ! git clone -b master https://github.com/edsonportosilva/ElectricCircuits
    ! sudo apt update
    ! sudo apt install imagemagick
    from os import chdir as cd
    cd('/content/ElectricCircuits/')
    ! pip install .

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
from circuit.utils import round_expr, symdisp, symplot, genGIF

# temp workaround
import warnings
from matplotlib import MatplotlibDeprecationWarning
warnings.filterwarnings('ignore', category=MatplotlibDeprecationWarning)

plt.rcParams['figure.figsize'] = 5.5, 5.5
plt.rcParams['legend.fontsize'] = 13
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = False

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # The complex exponential $e^{st}$

# %%
t = np.arange(0,7,0.01)
ω = 10
σ = 0

s = σ + 1j*ω

f = np.exp(s*t)

plt.figure()
plt.plot(t, f.real, label ='$\Re[f(t)]$')
plt.plot(t, f.imag, label ='$\Im[f(t)]$')
plt.xlim(min(t), max(t))
plt.grid()
plt.xlabel('tempo (s)')
plt.legend()

plt.figure()
plt.plot(f.real,f.imag, label ='$f(t)$')
plt.grid()
plt.xlabel('real')
plt.ylabel('imag')
plt.legend()

# %%
figName = './figures/complexExponential_sigma0.gif'

genGIF(f.real, f.imag, figName, xlabel='Real', ylabel='Imag.', 
       title = '$f(t)=e^{st}$,' + f's = σ + jω, σ = {σ}, ω = {ω}', squareAxes=True,
       fram=200, inter=80)

Image(figName, width=500)

# %%
figName = './figures/realPart_cplxExp_sigma0.gif'
genGIF(t, f.real, figName, xlabel='Tempo', ylabel='$\Re[e^{st}]$', 
       title = '$f(t)=\Re[e^{st}]$,' + f's = σ + jω, σ = {σ}, ω = {ω}', 
       squareAxes = False, fram=200, inter=80)

Image(figName, width=500)

# %%
figName = './figures/imagPart_cplxExp_sigma0.gif'
genGIF(t, f.imag, figName, xlabel='Tempo', ylabel='$\Im[e^{st}]$', 
       title = '$f(t)=\Im[e^{st}]$,' + f's = σ + jω, σ = {σ}, ω = {ω}', 
       squareAxes=False, fram=200, inter=80)

Image(figName, width=500)
